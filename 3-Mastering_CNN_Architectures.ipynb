# %% [markdown]
# # The CIFAR-10 Dataset

# %% [markdown]
# In this notebook, we will use the CIFAR-10 dataset, which consists of 60,000 32x32 color images in 10 classes. We will try two different CNN architectures to classify the images: a simple model and a deeper model.

# %% [markdown]
# ## Load the dataset

# %%
import tensorflow as tf

# Load the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Desktop/AI-projects/SDAIA-Large-Language-Models-Bootcamp/ai-env/lib/python3.13/site-packages/keras/src/utils/file_utils.py:354, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     353 try:
# --> 354     urlretrieve(origin, download_target, DLProgbar())
#     355 except urllib.error.HTTPError as e:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:214, in urlretrieve(url, filename, reporthook, data)
#     212 url_type, path = _splittype(url)
# --> 214 with contextlib.closing(urlopen(url, data)) as fp:
#     215     headers = fp.info()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     532 args = (dict, 'default', 'http_error_default') + orig_args
# --> 533 return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     465 func = getattr(handler, meth_name)
# --> 466 result = func(*args)
#     467 if result is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 503: Service Unavailable
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 import tensorflow as tf
#       2
#       3 # Load the CIFAR-10 dataset
# ----> 4 (train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
#       5
#       6
#
# File ~/Desktop/AI-projects/SDAIA-Large-Language-Models-Bootcamp/ai-env/lib/python3.13/site-packages/keras/src/datasets/cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
#      81 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File ~/Desktop/AI-projects/SDAIA-Large-Language-Models-Bootcamp/ai-env/lib/python3.13/site-packages/keras/src/utils/file_utils.py:356, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     354     urlretrieve(origin, download_target, DLProgbar())
#     355 except urllib.error.HTTPError as e:
# --> 356     raise Exception(error_msg.format(origin, e.code, e.msg))
#     357 except urllib.error.URLError as e:
#     358     raise Exception(error_msg.format(origin, e.errno, e.reason))
#
# Exception: URL fetch failure on https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz: 503 -- Service Unavailable

# %% [markdown]
# Let's normalize the pixel values

# %%
# Normalize the pixel values to the range [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# ## Modeling

# %% [markdown]
# Now, let's build and train two different CNN architectures:

# %% [markdown]
# ### Model 1 - Simple CNN:

# %%
# Build the Simple CNN architecture
model_simple = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model_simple.compile(optimizer='adam',
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])

# Train the model
history_simple = model_simple.fit(train_images, train_labels, epochs=10, batch_size=32, validation_data=(test_images, test_labels))

# Evaluate the model
test_loss_simple, test_accuracy_simple = model_simple.evaluate(test_images, test_labels)
print("Test accuracy (Simple CNN):", test_accuracy_simple)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.4809 - accuracy: 0.4673 - val_loss: 1.2374 - val_accuracy: 0.5624
# Epoch 2/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.1312 - accuracy: 0.6047 - val_loss: 1.0671 - val_accuracy: 0.6303
# Epoch 3/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.9969 - accuracy: 0.6534 - val_loss: 0.9985 - val_accuracy: 0.6537
# Epoch 4/10
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.9168 - accuracy: 0.6820 - val_loss: 0.9571 - val_accuracy: 0.6730
# Epoch 5/10
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.8505 - accuracy: 0.7048 - val_loss: 0.9349 - val_accuracy: 0.6780
# Epoch 6/10
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.7937 - accuracy: 0.7253 - val_loss: 0.9019 - val_accuracy: 0.6916
# Epoch 7/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.7461 - accuracy: 0.7418 - val_loss: 0.9591 - val_accuracy: 0.6753
# Epoch 8/10
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.7069 - accuracy: 0.7547 - val_loss: 0.9041 - val_accuracy: 0.6990
# Epoch 9/10
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.6686 - accuracy: 0.7684 - val_loss: 0.9237 - val_accuracy: 0.6958
# Epoch 10/10
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.6294 - accuracy: 0.7810 - val_loss: 0.9272 - val_accuracy: 0.6978
# 313/313 [==============================] - 4s 11ms/step - loss: 0.9272 - accuracy: 0.6978
# Test accuracy (Simple CNN): 0.6977999806404114

# %% [markdown]
# ## Model 2 - Deeper CNN:

# %%
# Build the Deeper CNN architecture
model_deeper = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model_deeper.compile(optimizer='adam',
                     loss='sparse_categorical_crossentropy',
                     metrics=['accuracy'])

# Train the model
history_deeper = model_deeper.fit(train_images, train_labels, epochs=10, batch_size=32, validation_data=(test_images, test_labels))

# Evaluate the model
test_loss_deeper, test_accuracy_deeper = model_deeper.evaluate(test_images, test_labels)
print("Test accuracy (Deeper CNN):", test_accuracy_deeper)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 82s 52ms/step - loss: 1.4919 - accuracy: 0.4566 - val_loss: 1.2090 - val_accuracy: 0.5618
# Epoch 2/10
# 1563/1563 [==============================] - 80s 51ms/step - loss: 1.0933 - accuracy: 0.6149 - val_loss: 1.0315 - val_accuracy: 0.6329
# Epoch 3/10
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.9310 - accuracy: 0.6756 - val_loss: 0.9268 - val_accuracy: 0.6797
# Epoch 4/10
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.8285 - accuracy: 0.7119 - val_loss: 0.9017 - val_accuracy: 0.6887
# Epoch 5/10
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.7403 - accuracy: 0.7402 - val_loss: 0.8844 - val_accuracy: 0.7007
# Epoch 6/10
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.6759 - accuracy: 0.7636 - val_loss: 0.8825 - val_accuracy: 0.6986
# Epoch 7/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.6170 - accuracy: 0.7857 - val_loss: 0.8458 - val_accuracy: 0.7102
# Epoch 8/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.5676 - accuracy: 0.7989 - val_loss: 0.8094 - val_accuracy: 0.7283
# Epoch 9/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 0.5217 - accuracy: 0.8173 - val_loss: 0.9133 - val_accuracy: 0.7062
# Epoch 10/10
# 1563/1563 [==============================] - 77s 50ms/step - loss: 0.4737 - accuracy: 0.8338 - val_loss: 0.9130 - val_accuracy: 0.7076
# 313/313 [==============================] - 5s 14ms/step - loss: 0.9130 - accuracy: 0.7076
# Test accuracy (Deeper CNN): 0.7075999975204468
